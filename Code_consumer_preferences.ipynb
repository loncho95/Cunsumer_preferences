# %%
import pandas as pd

# Define the file path
file_path = r'C:\Users\jlozan02\OneDrive - Kearney\Documents\Data-Analyst\Projects\Cunsumer_preferences\Consumer_preferences.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to verify the import
df.head()
# Out:
#    record              uuid  \
# 0     4.0  kyvbrw58n1wy9z3z
# 1     7.0  h5jgxj9yf2qukzzf
# 2     8.0  6enzmux28jkwahvx
# 3     9.0  bqy38s7dvj1f8xkw
# 4    10.0  xcbzgkfek6kk4jta
#
#                                              markers vC - Country VARIABLE  \
# 0  qualified,20220909_14:03_v38,/Overall/Total,/F...            France||FR
# 1  qualified,/FR/female,20220909_14:03_v38,/Overa...            France||FR
# 2  qualified,20220909_14:03_v38,/FR/fr_reg3,/Over...            France||FR
# 3  qualified,/FR/female,20220909_14:03_v38,/FR/fr...            France||FR
# 4  qualified,20220909_14:03_v38,/Overall/Total,/F...            France||FR
#
#   Country - Country from URL.  xsamplephase - Hidden punch for Samplephase  \
# 0                  France||FR                                          NaN
# 1                  France||FR                                          NaN
# 2                  France||FR                                          NaN
# 3                  France||FR                                          NaN
# 4                  France||FR                                          NaN
#
#   D1 - Are you? D2 - Where do you live? xREGION - Region hidden  \
# 0      Un homme               Aquitaine               Sud Ouest
# 1     Une femme             Rhône-Alpes                 Sud Est
# 2      Un homme      Nord Pas de Calais                Nord Est
# 3     Une femme        Pays de la Loire              Nord Ouest
# 4      Un homme     Languedoc-Rousillon                 Sud Est
#
#   D3 - What is the number of inhabitants of the city in which you live?  ...  \
# 0                          10 000 à 49 999 habitants                     ...
# 1                          10 000 à 49 999 habitants                     ...
# 2                            5 000 à 9 999 habitants                     ...
# 3                            2 000 à 4 999 habitants                     ...
# 4                          10 000 à 49 999 habitants                     ...
#
#    Unnamed: 503 Bio Translation Local Translation Alternative Translation  \
# 0           NaN             3.0               3.0                     1.0
# 1           NaN             2.0               2.0                     0.0
# 2           NaN             2.0               3.0                     2.0
# 3           NaN             1.0               1.0                     1.0
# 4           NaN             2.0               2.0                     2.0
#
#    Unnamed: 507  Neutralization mark criterion  Unnamed: 509  \
# 0           NaN                              1           NaN
# 1           NaN                              1           NaN
# 2           NaN                              1           NaN
# 3           NaN                              1           NaN
# 4           NaN                              1           NaN
#
#    Restatement # of habitants  Restatement revenues  Restatement studies
# 0                         4.0                   6.0                  4.0
# 1                         4.0                   1.0                  2.0
# 2                         3.0                   2.0                  3.0
# 3                         2.0                   2.0                  2.0
# 4                         4.0                   2.0                  3.0
#
# [5 rows x 513 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Columns: 513 entries, record to Restatement studies
# dtypes: float64(300), int64(2), object(211)
# memory usage: 19.6+ MB
